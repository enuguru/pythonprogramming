# %%
for num in range(10):
    print(num*num,end=" ")
# Out:
# 0 1 4 9 16 25 36 49 64 81

# %%
print([num*num for num in range(10)])
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
for num in range(101):
    if
