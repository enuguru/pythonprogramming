# %%
def calculate_area(length: float, width: float) -> float:
    """Calculate the area of a rectangle with type hints."""
    return length * width

print(calculate_area(5.0, 3.2))
# Out:
# 16.0

# %%
def calculate_area(length: float, width: float) -> float:
    """Calculate the area of a rectangle with type hints."""
    return length * width

print(calculate_area(5.0, 3.2))
# Out:
# 16.0
